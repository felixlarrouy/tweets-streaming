# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Stream-tweets-with-Tweepy" data-toc-modified-id="Stream-tweets-with-Tweepy-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Stream tweets with Tweepy</a></span></li><li><span><a href="#Spark-streaming" data-toc-modified-id="Spark-streaming-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Spark streaming</a></span></li></ul></div>

# %%
import findspark
findspark.init('/home/felixlarrouy/spark-2.1.0-bin-hadoop2.7')

from pyspark import SparkContext
from pyspark.streaming import StreamingContext

sc = SparkContext()
ssc = StreamingContext(sc, 5) # 10 seconds batch interval
# socket_stream = ssc.socketTextStream("localhost", 5555)
host = "localhost"
port = 5555  

lines = ssc.socketTextStream(host, port)
words = lines.flatMap(lambda line: line.split())
pairs = words.map(lambda word: (word, 1))
wordCounts = pairs.reduceByKey(lambda x, y: x + y)

# Print the first ten elements of each RDD generated in this DStream to the console
wordCounts.pprint()

# %%
ssc.start()             
ssc.awaitTermination()
# Out:
# -------------------------------------------
# Time: 2018-11-06 12:15:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:15:40
# -------------------------------------------
# (u'wenn', 1)
# (u'RT', 2)
# (u'this', 1)
# (u'wlh', 1)
# (u'me', 1)
# (u'pr', 1)
# (u'llegaban', 1)
# (u'ai', 1)
# (u'a', 2)
# (u'Vereinen', 1)
# ...
#
# -------------------------------------------
# Time: 2018-11-06 12:15:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:15:50
# -------------------------------------------
# (u'couilles', 1)
# (u'sort', 1)
# (u'beatbox', 1)
# (u'pr', 1)
# (u'comme', 1)
# (u'Messi', 4)
# (u'a', 1)
# (u'kkkk', 1)
# (u'bin', 1)
# (u'wlh', 1)
# ...
#
# -------------------------------------------
# Time: 2018-11-06 12:15:55
# -------------------------------------------
# (u'siga', 1)
# (u'and', 2)
# (u'scored', 1)
# (u'i', 1)
# (u'https://t.co/HsJKrJaZigRT', 1)
# (u'qui', 1)
# (u'feel', 1)
# (u'y', 1)
# (u'tal', 1)
# (u'not', 1)
# ...
#
# -------------------------------------------
# Time: 2018-11-06 12:16:00
# -------------------------------------------
# (u'Stones', 1)
# (u'autre', 1)
# (u'@Alfremartinezz:', 1)
# (u'\U0001f3a9', 1)
# (u'this', 1)
# (u'wlh', 1)
# (u'pr', 1)
# (u'Siro.', 1)
# (u'vus.', 1)
# (u'partido', 1)
# ...
#
# -------------------------------------------
# Time: 2018-11-06 12:16:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:16:10
# -------------------------------------------
# (u'couilles', 1)
# (u'Siro.', 1)
# (u'and', 1)
# (u'sort', 2)
# (u'And', 1)
# (u'ya', 1)
# (u'qui', 1)
# (u'pelouse', 1)
# (u'pr', 1)
# (u'comme', 2)
# ...
#
# -------------------------------------------
# Time: 2018-11-06 12:16:15
# -------------------------------------------
# (u'pr', 1)
# (u'couilles', 1)
# (u'Messi', 1)
# (u'wlh', 1)
# (u'a', 1)
# (u'qui', 1)
# (u'Comprendra', 1)
# (u'rajel', 1)
# (u'Messi..', 1)
# (u'c', 3)
# ...
#
# -------------------------------------------
# Time: 2018-11-06 12:16:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:16:25
# -------------------------------------------
# (u'Messi', 1)
# (u'913k', 1)
# (u'@FrauBraunn:', 1)
# (u'sold', 3)
# (u'Suarez', 1)
# (u'Azul', 1)
# (u'November', 1)
# (u'\U0001f602\U0001f602RT', 1)
# (u'340k', 1)
# (u'now', 2)
# ...
#
# -------------------------------------------
# Time: 2018-11-06 12:16:30
# -------------------------------------------
# (u'and', 1)
# (u'messi\xe2nicos', 1)
# (u'banquilloRT', 1)
# (u'Messi', 3)
# (u'sort', 1)
# (u'comme', 1)
# (u'y', 1)
# (u'Waters.\u2026RT', 1)
# (u'malucos,', 1)
# (u't\xe3o', 1)
# ...
#
# -------------------------------------------
# Time: 2018-11-06 12:16:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:16:40
# -------------------------------------------
# (u'and', 1)
# (u'couilles', 1)
# (u'federal', 1)
# (u'this', 1)
# (u'me', 1)
# (u'pr', 1)
# (u'wlh', 1)
# (u'qui', 1)
# (u'a', 1)
# (u'go', 1)
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-1c963c6d72b8> in <module>()
#       1 ssc.start()
# ----> 2 ssc.awaitTermination()
#
# /home/felixlarrouy/spark-2.1.0-bin-hadoop2.7/python/pyspark/streaming/context.pyc in awaitTermination(self, timeout)
#     204         """
#     205         if timeout is None:
# --> 206             self._jssc.awaitTermination()
#     207         else:
#     208             self._jssc.awaitTerminationOrTimeout(int(timeout * 1000))
#
# /home/felixlarrouy/spark-2.1.0-bin-hadoop2.7/python/lib/py4j-0.10.4-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1129             proto.END_COMMAND_PART
#    1130
# -> 1131         answer = self.gateway_client.send_command(command)
#    1132         return_value = get_return_value(
#    1133             answer, self.gateway_client, self.target_id, self.name)
#
# /home/felixlarrouy/spark-2.1.0-bin-hadoop2.7/python/lib/py4j-0.10.4-src.zip/py4j/java_gateway.py in send_command(self, command, retry, binary)
#     881         connection = self._get_connection()
#     882         try:
# --> 883             response = connection.send_command(command)
#     884             if binary:
#     885                 return response, self._create_connection_guard(connection)
#
# /home/felixlarrouy/spark-2.1.0-bin-hadoop2.7/python/lib/py4j-0.10.4-src.zip/py4j/java_gateway.py in send_command(self, command)
#    1026
#    1027         try:
# -> 1028             answer = smart_decode(self.stream.readline()[:-1])
#    1029             logger.debug("Answer received: {0}".format(answer))
#    1030             if answer.startswith(proto.RETURN_MESSAGE):
#
# /home/felixlarrouy/anaconda2/lib/python2.7/socket.pyc in readline(self, size)
#     449             while True:
#     450                 try:
# --> 451                     data = self._sock.recv(self._rbufsize)
#     452                 except error, e:
#     453                     if e.args[0] == EINTR:
#
# KeyboardInterrupt:
# -------------------------------------------
# Time: 2018-11-06 12:16:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:16:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:16:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:17:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:17:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:17:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:17:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:17:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:17:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:17:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:17:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-11-06 12:17:40
# -------------------------------------------
